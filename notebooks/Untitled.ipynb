# %%
import os
import sys
sys.path.insert(0, os.path.abspath('../'))
from gooutsafe import create_app
app = create_app()

# %%
from gooutsafe.forms.user import UserForm

form = UserForm()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-5-82ad94617972> in <module>
#       1 from gooutsafe.forms.user import UserForm
#       2
# ----> 3 form = UserForm()
#
# ~/PycharmProjects/GoOutSafe/venv/lib/python3.8/site-packages/wtforms/form.py in __call__(cls, *args, **kwargs)
#     206                     bases.append(mro_class.Meta)
#     207             cls._wtforms_meta = type('Meta', tuple(bases), {})
# --> 208         return type.__call__(cls, *args, **kwargs)
#     209
#     210     def __setattr__(cls, name, value):
#
# ~/PycharmProjects/GoOutSafe/venv/lib/python3.8/site-packages/flask_wtf/form.py in __init__(self, formdata, **kwargs)
#      85             kwargs['meta'].setdefault('csrf', csrf_enabled)
#      86
# ---> 87         super(FlaskForm, self).__init__(formdata=formdata, **kwargs)
#      88
#      89     def is_submitted(self):
#
# ...
